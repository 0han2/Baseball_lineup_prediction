# %% [markdown]
# # 라이브러리

# %%
# %lsmagic
# %pip install -q selenium
# %pip install beautifulsoup4
# %pip install lxml
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.7/467.7 kB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (4.9.4)

# %%
import selenium
from selenium import webdriver as wd
from selenium.webdriver.common.by import By
import time
import pandas as pd
import os



selenium.__version__
# Out:
# '4.22.0'

# %% [markdown]
# # KIA

# %%
# 폴더 생성
folder_name = 'KIA'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# 1 Chrome 열기
driver = wd.Chrome()

teps = ['HitterBasic/Basic1', 'HitterBasic/Basic2', 'HitterBasic/Detail1', 'Defense/Basic', 'Runner/Basic']
Hitter_years = [37, 38, 39, 40, 41, 42]
Defense_years = Hitter_years
Runner_years = Defense_years
batting_order = range(2,14)
team = ['HT']

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 열 이름 사전
column_translations = {
    # 타자기록
    '2B': '2루타', '3B': '3루타', 'AB': '타수', 'AO': '뜬공', 'AVG': '타율',
    'BB': '볼넷', 'BB/K': '볼넷/삼진', 'CS': '도루실패', 'E': '실책', 'G': '경기',
    'GDP': '병살타', 'GO': '땅볼', 'GO/AO': '땅볼/뜬공', 'GPA': '(1.8x출루율+장타율)/4',
    'GW RBI': '결승타', 'H': '안타', 'HBP': '사구', 'HR': '홈런', 'IBB': '고의4구',
    'ISOP': '순수장타율', 'MH': '멀티히트', 'OBP': '출루율', 'OPS': '출루율+장타율',
    'P/PA': '투구수/타석', 'PA': '타석', 'PH-BA': '대타타율', 'R': '득점', 'RBI': '타점',
    'RISP': '득점권타율', 'SAC': '희생번트', 'SB': '도루', 'SF': '희생플라이', 'SLG': '장타율',
    'SO': '삼진', 'TB': '루타', 'XBH': '장타', 'XR': '추정득점',
    # 수비기록
    'A': '어시스트', 'CS': '도루저지', 'CS%': '도루저지율', 'DP': '병살', 'FPCT': '수비율',
    'GS': '선발경기', 'PB': '포일', 'PKO': '견제사', 'PO': '풋아웃', 'POS': '포지션',
    'SB': '도루허용', 'IP' : '수비이닝',
    # 주루기록
    'OOB': '주루사', 'SBA': '도루시도', 'SB%': '도루성공률'
}

# 타순 매핑
order_mapping = {
    2: '1번', 3: '2번', 4: '3번', 5: '4번', 6: '5번',
    7: '6번', 8: '7번', 9: '8번', 10: '9번',
    11: '상위(1~2번)', 12: '중심(3~5번)', 13: '하위(6~9번)'
}

# 사이트 접속
for tep in teps[:2] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('HT'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # HitterBasic/Basic2일 경우에만 불필요한 열 제거
            if tep == 'HitterBasic/Basic2':
                df = df.drop(columns=['순위', '선수명', '팀명', 'AVG'])

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) >= 4:  # HitterBasic/Basic2의 데이터가 존재하는 경우
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        df3 = dfs[2]  # HitterBasic/Basic2의 page1 결과
        df4 = dfs[3]  # HitterBasic/Basic2의 page2 결과
        Basic1_df = pd.concat([df1, df2], axis=0)
        Basic2_df = pd.concat([df3, df4], axis=0)
        final_df = pd.concat([Basic1_df, Basic2_df], axis=1)
    else:
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        final_df = pd.concat([df1, df2], axis=1)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'KIA_hitter_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[2:3] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('HT'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # HitterBasic/Detail1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Detail1c의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'KIA_hitter_detail_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[:1] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('HT'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 타순별 선택
        Situation_selector = '#cphContents_cphContents_cphContents_ddlSituation_ddlSituation > option:nth-child(14)'
        driver.find_element(By.CSS_SELECTOR, Situation_selector).click()
        time.sleep(3)

        for order in batting_order:
            # 타순 선택
            Batting_order_selector = f'#cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail > option:nth-child({order})'
            driver.find_element(By.CSS_SELECTOR, Batting_order_selector).click()
            time.sleep(3)

            # 1페이지로 돌아가기
            first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
            first_page_button.click()
            time.sleep(3)

            # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
            for page in range(1, 3):
                if page > 1:
                    try:
                        next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                        next_page_button.click()
                        time.sleep(3)
                    except:
                        break  # 페이지 버튼이 없는 경우 루프를 종료

                # 결과 테이블 가져오기
                result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
                table_html = result_table.get_attribute('outerHTML')

                # DataFrame으로 변환하여 리스트에 추가
                df = pd.read_html(table_html, encoding='utf-8')[0]

                # 타순 열 추가
                df['타순'] = order_mapping[order]

                # 결과를 리스트에 추가
                result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 결과 데이터프레임을 연도별로 합쳐서 각각의 CSV 파일로 저장
for year, dfs in result_dfs.items():
    if dfs:  # dfs 리스트가 비어있지 않을 때만 처리
        combined_df = pd.concat(dfs, axis=0)
        combined_df.rename(columns=column_translations, inplace=True)
        combined_df = combined_df.astype(str)
        combined_df.to_csv(os.path.join(folder_name, f'KIA_batting_order_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[3:4]:
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 수비 기록 접속
    for year_index, year in enumerate(Defense_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('HT'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 5):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 팀이 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if not dfs:
        continue  # dfs 리스트가 비어 있는 경우 반복문을 건너뜁니다.

    if len(dfs) >= 4 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        df4 = dfs[3]  # Defense/Basic의 page4 결과
        final_df = pd.concat([df1, df2, df3, df4], axis=0)
    elif len(dfs) >= 3 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        final_df = pd.concat([df1, df2, df3], axis=0)
    else :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'KIA_defense_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[4:] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 주루 기록 접속
    for year_index, year in enumerate(Runner_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('HT'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        df2 = dfs[1]  # Runner/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)
    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'KIA_runner_2024.csv'), index=False, encoding='cp949')

# 드라이버 종료
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-3-9a23c0d1da78> in <cell line: 7>()
#       5
#       6 # 1 Chrome 열기
# ----> 7 driver = wd.Chrome()
#       8
#       9 teps = ['HitterBasic/Basic1', 'HitterBasic/Basic2', 'HitterBasic/Detail1', 'Defense/Basic', 'Runner/Basic']
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, options, service, keep_alive)
#      43         options = options if options else Options()
#      44
# ---> 45         super().__init__(
#      46             browser_name=DesiredCapabilities.CHROME["browserName"],
#      47             vendor_prefix="goog",
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      64
#      65         try:
# ---> 66             super().__init__(command_executor=executor, options=options)
#      67         except Exception:
#      68             self.quit()
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, keep_alive, file_detector, options)
#     210         self._authenticator_id = None
#     211         self.start_client()
# --> 212         self.start_session(capabilities)
#     213
#     214         self._websocket_connection = None
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/webdriver.py in start_session(self, capabilities)
#     297
#     298         caps = _create_caps(capabilities)
# --> 299         response = self.execute(Command.NEW_SESSION, caps)["value"]
#     300         self.session_id = response.get("sessionId")
#     301         self.caps = response.get("capabilities")
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     352         response = self.command_executor.execute(driver_command, params)
#     353         if response:
# --> 354             self.error_handler.check_response(response)
#     355             response["value"] = self._unwrap_value(response.get("value", None))
#     356             return response
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created: Chrome failed to start: exited normally.
#   (session not created: DevToolsActivePort file doesn't exist)
#   (The process started from chrome location /root/.cache/selenium/chrome/linux64/126.0.6478.63/chrome is no longer running, so ChromeDriver is assuming that Chrome has crashed.)
# Stacktrace:
# #0 0x57f4d396a69a <unknown>
# #1 0x57f4d364d0dc <unknown>
# #2 0x57f4d368202a <unknown>
# #3 0x57f4d367e43b <unknown>
# #4 0x57f4d36c8ef9 <unknown>
# #5 0x57f4d36bc613 <unknown>
# #6 0x57f4d368c4f7 <unknown>
# #7 0x57f4d368ce4e <unknown>
# #8 0x57f4d393086b <unknown>
# #9 0x57f4d3934911 <unknown>
# #10 0x57f4d391c35e <unknown>
# #11 0x57f4d3935472 <unknown>
# #12 0x57f4d3900cbf <unknown>
# #13 0x57f4d395a098 <unknown>
# #14 0x57f4d395a270 <unknown>
# #15 0x57f4d39697cc <unknown>
# #16 0x7abb5db87ac3 <unknown>

# %% [markdown]
# # KT

# %%
# 폴더 생성
folder_name = 'KT'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# 1 Chrome 열기
driver = wd.Chrome()

teps = ['HitterBasic/Basic1', 'HitterBasic/Basic2', 'HitterBasic/Detail1', 'Defense/Basic', 'Runner/Basic']
Hitter_years = [37, 38, 39, 40, 41, 42]
Defense_years = Hitter_years
Runner_years = Defense_years
batting_order = range(2,14)
team = ['KT']

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 열 이름 사전
column_translations = {
    # 타자기록
    '2B': '2루타', '3B': '3루타', 'AB': '타수', 'AO': '뜬공', 'AVG': '타율',
    'BB': '볼넷', 'BB/K': '볼넷/삼진', 'CS': '도루실패', 'E': '실책', 'G': '경기',
    'GDP': '병살타', 'GO': '땅볼', 'GO/AO': '땅볼/뜬공', 'GPA': '(1.8x출루율+장타율)/4',
    'GW RBI': '결승타', 'H': '안타', 'HBP': '사구', 'HR': '홈런', 'IBB': '고의4구',
    'ISOP': '순수장타율', 'MH': '멀티히트', 'OBP': '출루율', 'OPS': '출루율+장타율',
    'P/PA': '투구수/타석', 'PA': '타석', 'PH-BA': '대타타율', 'R': '득점', 'RBI': '타점',
    'RISP': '득점권타율', 'SAC': '희생번트', 'SB': '도루', 'SF': '희생플라이', 'SLG': '장타율',
    'SO': '삼진', 'TB': '루타', 'XBH': '장타', 'XR': '추정득점',
    # 수비기록
    'A': '어시스트', 'CS': '도루저지', 'CS%': '도루저지율', 'DP': '병살', 'FPCT': '수비율',
    'GS': '선발경기', 'PB': '포일', 'PKO': '견제사', 'PO': '풋아웃', 'POS': '포지션',
    'SB': '도루허용', 'IP' : '수비이닝',
    # 주루기록
    'OOB': '주루사', 'SBA': '도루시도', 'SB%': '도루성공률'
}

# 타순 매핑
order_mapping = {
    2: '1번', 3: '2번', 4: '3번', 5: '4번', 6: '5번',
    7: '6번', 8: '7번', 9: '8번', 10: '9번',
    11: '상위(1~2번)', 12: '중심(3~5번)', 13: '하위(6~9번)'
}

# 사이트 접속
for tep in teps[:2] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('KT'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # HitterBasic/Basic2일 경우에만 불필요한 열 제거
            if tep == 'HitterBasic/Basic2':
                df = df.drop(columns=['순위', '선수명', '팀명', 'AVG'])

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) >= 4:  # HitterBasic/Basic2의 데이터가 존재하는 경우
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        df3 = dfs[2]  # HitterBasic/Basic2의 page1 결과
        df4 = dfs[3]  # HitterBasic/Basic2의 page2 결과
        Basic1_df = pd.concat([df1, df2], axis=0)
        Basic2_df = pd.concat([df3, df4], axis=0)
        final_df = pd.concat([Basic1_df, Basic2_df], axis=1)
    else:
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        final_df = pd.concat([df1, df2], axis=1)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'KT_hitter_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[2:3] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('KT'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # HitterBasic/Detail1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Detail1c의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'KT_hitter_detail_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[:1] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('KT'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 타순별 선택
        Situation_selector = '#cphContents_cphContents_cphContents_ddlSituation_ddlSituation > option:nth-child(14)'
        driver.find_element(By.CSS_SELECTOR, Situation_selector).click()
        time.sleep(3)

        for order in batting_order:
            # 타순 선택
            Batting_order_selector = f'#cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail > option:nth-child({order})'
            driver.find_element(By.CSS_SELECTOR, Batting_order_selector).click()
            time.sleep(3)

            # 1페이지로 돌아가기
            first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
            first_page_button.click()
            time.sleep(3)

            # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
            for page in range(1, 3):
                if page > 1:
                    try:
                        next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                        next_page_button.click()
                        time.sleep(3)
                    except:
                        break  # 페이지 버튼이 없는 경우 루프를 종료

                # 결과 테이블 가져오기
                result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
                table_html = result_table.get_attribute('outerHTML')

                # DataFrame으로 변환하여 리스트에 추가
                df = pd.read_html(table_html, encoding='utf-8')[0]

                # 타순 열 추가
                df['타순'] = order_mapping[order]

                # 결과를 리스트에 추가
                result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 결과 데이터프레임을 연도별로 합쳐서 각각의 CSV 파일로 저장
for year, dfs in result_dfs.items():
    if dfs:  # dfs 리스트가 비어있지 않을 때만 처리
        combined_df = pd.concat(dfs, axis=0)
        combined_df.rename(columns=column_translations, inplace=True)
        combined_df = combined_df.astype(str)
        combined_df.to_csv(os.path.join(folder_name, f'KT_batting_order_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[3:4]:
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 수비 기록 접속
    for year_index, year in enumerate(Defense_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('KT'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 5):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 팀이 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if not dfs:
        continue  # dfs 리스트가 비어 있는 경우 반복문을 건너뜁니다.

    if len(dfs) >= 4 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        df4 = dfs[3]  # Defense/Basic의 page4 결과
        final_df = pd.concat([df1, df2, df3, df4], axis=0)
    elif len(dfs) >= 3 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        final_df = pd.concat([df1, df2, df3], axis=0)
    else :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'KT_defense_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[4:] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 주루 기록 접속
    for year_index, year in enumerate(Runner_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('KT'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        df2 = dfs[1]  # Runner/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)
    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'KT_runner_2024.csv'), index=False, encoding='cp949')

# 드라이버 종료
driver.quit()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:162: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:162: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:388: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\306808172.py:388: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]

# %% [markdown]
# # LG

# %%
# 폴더 생성
folder_name = 'LG'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# 1 Chrome 열기
driver = wd.Chrome()

teps = ['HitterBasic/Basic1', 'HitterBasic/Basic2', 'HitterBasic/Detail1', 'Defense/Basic', 'Runner/Basic']
Hitter_years = [37, 38, 39, 40, 41, 42]
Defense_years = Hitter_years
Runner_years = Defense_years
batting_order = range(2,14)
team = ['LG']

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 열 이름 사전
column_translations = {
    # 타자기록
    '2B': '2루타', '3B': '3루타', 'AB': '타수', 'AO': '뜬공', 'AVG': '타율',
    'BB': '볼넷', 'BB/K': '볼넷/삼진', 'CS': '도루실패', 'E': '실책', 'G': '경기',
    'GDP': '병살타', 'GO': '땅볼', 'GO/AO': '땅볼/뜬공', 'GPA': '(1.8x출루율+장타율)/4',
    'GW RBI': '결승타', 'H': '안타', 'HBP': '사구', 'HR': '홈런', 'IBB': '고의4구',
    'ISOP': '순수장타율', 'MH': '멀티히트', 'OBP': '출루율', 'OPS': '출루율+장타율',
    'P/PA': '투구수/타석', 'PA': '타석', 'PH-BA': '대타타율', 'R': '득점', 'RBI': '타점',
    'RISP': '득점권타율', 'SAC': '희생번트', 'SB': '도루', 'SF': '희생플라이', 'SLG': '장타율',
    'SO': '삼진', 'TB': '루타', 'XBH': '장타', 'XR': '추정득점',
    # 수비기록
    'A': '어시스트', 'CS': '도루저지', 'CS%': '도루저지율', 'DP': '병살', 'FPCT': '수비율',
    'GS': '선발경기', 'PB': '포일', 'PKO': '견제사', 'PO': '풋아웃', 'POS': '포지션',
    'SB': '도루허용', 'IP' : '수비이닝',
    # 주루기록
    'OOB': '주루사', 'SBA': '도루시도', 'SB%': '도루성공률'
}

# 타순 매핑
order_mapping = {
    2: '1번', 3: '2번', 4: '3번', 5: '4번', 6: '5번',
    7: '6번', 8: '7번', 9: '8번', 10: '9번',
    11: '상위(1~2번)', 12: '중심(3~5번)', 13: '하위(6~9번)'
}

# 사이트 접속
for tep in teps[:2] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('LG'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # HitterBasic/Basic2일 경우에만 불필요한 열 제거
            if tep == 'HitterBasic/Basic2':
                df = df.drop(columns=['순위', '선수명', '팀명', 'AVG'])

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) >= 4:  # HitterBasic/Basic2의 데이터가 존재하는 경우
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        df3 = dfs[2]  # HitterBasic/Basic2의 page1 결과
        df4 = dfs[3]  # HitterBasic/Basic2의 page2 결과
        Basic1_df = pd.concat([df1, df2], axis=0)
        Basic2_df = pd.concat([df3, df4], axis=0)
        final_df = pd.concat([Basic1_df, Basic2_df], axis=1)
    else:
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        final_df = pd.concat([df1, df2], axis=1)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'LG_hitter_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[2:3] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('LG'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # HitterBasic/Detail1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Detail1c의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'LG_hitter_detail_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[:1] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('LG'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 타순별 선택
        Situation_selector = '#cphContents_cphContents_cphContents_ddlSituation_ddlSituation > option:nth-child(14)'
        driver.find_element(By.CSS_SELECTOR, Situation_selector).click()
        time.sleep(3)

        for order in batting_order:
            # 타순 선택
            Batting_order_selector = f'#cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail > option:nth-child({order})'
            driver.find_element(By.CSS_SELECTOR, Batting_order_selector).click()
            time.sleep(3)

            # 1페이지로 돌아가기
            first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
            first_page_button.click()
            time.sleep(3)

            # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
            for page in range(1, 3):
                if page > 1:
                    try:
                        next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                        next_page_button.click()
                        time.sleep(3)
                    except:
                        break  # 페이지 버튼이 없는 경우 루프를 종료

                # 결과 테이블 가져오기
                result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
                table_html = result_table.get_attribute('outerHTML')

                # DataFrame으로 변환하여 리스트에 추가
                df = pd.read_html(table_html, encoding='utf-8')[0]

                # 타순 열 추가
                df['타순'] = order_mapping[order]

                # 결과를 리스트에 추가
                result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 결과 데이터프레임을 연도별로 합쳐서 각각의 CSV 파일로 저장
for year, dfs in result_dfs.items():
    if dfs:  # dfs 리스트가 비어있지 않을 때만 처리
        combined_df = pd.concat(dfs, axis=0)
        combined_df.rename(columns=column_translations, inplace=True)
        combined_df = combined_df.astype(str)
        combined_df.to_csv(os.path.join(folder_name, f'LG_batting_order_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[3:4]:
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 수비 기록 접속
    for year_index, year in enumerate(Defense_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('LG'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 5):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 팀이 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if not dfs:
        continue  # dfs 리스트가 비어 있는 경우 반복문을 건너뜁니다.

    if len(dfs) >= 4 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        df4 = dfs[3]  # Defense/Basic의 page4 결과
        final_df = pd.concat([df1, df2, df3, df4], axis=0)
    elif len(dfs) >= 3 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        final_df = pd.concat([df1, df2, df3], axis=0)
    else :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'LG_defense_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[4:] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 주루 기록 접속
    for year_index, year in enumerate(Runner_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('LG'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        df2 = dfs[1]  # Runner/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)
    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'LG_runner_2024.csv'), index=False, encoding='cp949')

# 드라이버 종료
driver.quit()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3968852679.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3968852679.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3968852679.py:162: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3968852679.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3968852679.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3968852679.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3968852679.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3968852679.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3968852679.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3968852679.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3968852679.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3968852679.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3968852679.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3968852679.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3968852679.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3968852679.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3968852679.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3968852679.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3968852679.py:388: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]

# %% [markdown]
# # NC

# %%
# 폴더 생성
folder_name = 'NC'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# 1 Chrome 열기
driver = wd.Chrome()

teps = ['HitterBasic/Basic1', 'HitterBasic/Basic2', 'HitterBasic/Detail1', 'Defense/Basic', 'Runner/Basic']
Hitter_years = [37, 38, 39, 40, 41, 42]
Defense_years = Hitter_years
Runner_years = Defense_years
batting_order = range(2,14)
team = ['NC']

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 열 이름 사전
column_translations = {
    # 타자기록
    '2B': '2루타', '3B': '3루타', 'AB': '타수', 'AO': '뜬공', 'AVG': '타율',
    'BB': '볼넷', 'BB/K': '볼넷/삼진', 'CS': '도루실패', 'E': '실책', 'G': '경기',
    'GDP': '병살타', 'GO': '땅볼', 'GO/AO': '땅볼/뜬공', 'GPA': '(1.8x출루율+장타율)/4',
    'GW RBI': '결승타', 'H': '안타', 'HBP': '사구', 'HR': '홈런', 'IBB': '고의4구',
    'ISOP': '순수장타율', 'MH': '멀티히트', 'OBP': '출루율', 'OPS': '출루율+장타율',
    'P/PA': '투구수/타석', 'PA': '타석', 'PH-BA': '대타타율', 'R': '득점', 'RBI': '타점',
    'RISP': '득점권타율', 'SAC': '희생번트', 'SB': '도루', 'SF': '희생플라이', 'SLG': '장타율',
    'SO': '삼진', 'TB': '루타', 'XBH': '장타', 'XR': '추정득점',
    # 수비기록
    'A': '어시스트', 'CS': '도루저지', 'CS%': '도루저지율', 'DP': '병살', 'FPCT': '수비율',
    'GS': '선발경기', 'PB': '포일', 'PKO': '견제사', 'PO': '풋아웃', 'POS': '포지션',
    'SB': '도루허용', 'IP' : '수비이닝',
    # 주루기록
    'OOB': '주루사', 'SBA': '도루시도', 'SB%': '도루성공률'
}

# 타순 매핑
order_mapping = {
    2: '1번', 3: '2번', 4: '3번', 5: '4번', 6: '5번',
    7: '6번', 8: '7번', 9: '8번', 10: '9번',
    11: '상위(1~2번)', 12: '중심(3~5번)', 13: '하위(6~9번)'
}

# 사이트 접속
for tep in teps[:2] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('NC'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # HitterBasic/Basic2일 경우에만 불필요한 열 제거
            if tep == 'HitterBasic/Basic2':
                df = df.drop(columns=['순위', '선수명', '팀명', 'AVG'])

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) >= 4:  # HitterBasic/Basic2의 데이터가 존재하는 경우
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        df3 = dfs[2]  # HitterBasic/Basic2의 page1 결과
        df4 = dfs[3]  # HitterBasic/Basic2의 page2 결과
        Basic1_df = pd.concat([df1, df2], axis=0)
        Basic2_df = pd.concat([df3, df4], axis=0)
        final_df = pd.concat([Basic1_df, Basic2_df], axis=1)
    else:
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        final_df = pd.concat([df1, df2], axis=1)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'NC_hitter_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[2:3] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('NC'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # HitterBasic/Detail1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Detail1c의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'NC_hitter_detail_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[:1] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('NC'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 타순별 선택
        Situation_selector = '#cphContents_cphContents_cphContents_ddlSituation_ddlSituation > option:nth-child(14)'
        driver.find_element(By.CSS_SELECTOR, Situation_selector).click()
        time.sleep(3)

        for order in batting_order:
            # 타순 선택
            Batting_order_selector = f'#cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail > option:nth-child({order})'
            driver.find_element(By.CSS_SELECTOR, Batting_order_selector).click()
            time.sleep(3)

            # 1페이지로 돌아가기
            first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
            first_page_button.click()
            time.sleep(3)

            # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
            for page in range(1, 3):
                if page > 1:
                    try:
                        next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                        next_page_button.click()
                        time.sleep(3)
                    except:
                        break  # 페이지 버튼이 없는 경우 루프를 종료

                # 결과 테이블 가져오기
                result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
                table_html = result_table.get_attribute('outerHTML')

                # DataFrame으로 변환하여 리스트에 추가
                df = pd.read_html(table_html, encoding='utf-8')[0]

                # 타순 열 추가
                df['타순'] = order_mapping[order]

                # 결과를 리스트에 추가
                result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 결과 데이터프레임을 연도별로 합쳐서 각각의 CSV 파일로 저장
for year, dfs in result_dfs.items():
    if dfs:  # dfs 리스트가 비어있지 않을 때만 처리
        combined_df = pd.concat(dfs, axis=0)
        combined_df.rename(columns=column_translations, inplace=True)
        combined_df = combined_df.astype(str)
        combined_df.to_csv(os.path.join(folder_name, f'NC_batting_order_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[3:4]:
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 수비 기록 접속
    for year_index, year in enumerate(Defense_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('NC'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 5):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 팀이 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if not dfs:
        continue  # dfs 리스트가 비어 있는 경우 반복문을 건너뜁니다.

    if len(dfs) >= 4 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        df4 = dfs[3]  # Defense/Basic의 page4 결과
        final_df = pd.concat([df1, df2, df3, df4], axis=0)
    elif len(dfs) >= 3 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        final_df = pd.concat([df1, df2, df3], axis=0)
    else :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'NC_defense_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[4:] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 주루 기록 접속
    for year_index, year in enumerate(Runner_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('NC'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        df2 = dfs[1]  # Runner/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)
    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'NC_runner_2024.csv'), index=False, encoding='cp949')

# 드라이버 종료
driver.quit()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\364576641.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\364576641.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\364576641.py:162: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\364576641.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\364576641.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\364576641.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\364576641.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\364576641.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\364576641.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\364576641.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\364576641.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\364576641.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\364576641.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\364576641.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\364576641.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\364576641.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\364576641.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\364576641.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\364576641.py:388: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]

# %% [markdown]
# # SSG

# %%
# 폴더 생성
folder_name = 'SSG'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# 1 Chrome 열기
driver = wd.Chrome()

teps = ['HitterBasic/Basic1', 'HitterBasic/Basic2', 'HitterBasic/Detail1', 'Defense/Basic', 'Runner/Basic']
Hitter_years = [37, 38, 39, 40, 41, 42]
Defense_years = Hitter_years
Runner_years = Defense_years
batting_order = range(2,14)
team = ['SK']

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 열 이름 사전
column_translations = {
    # 타자기록
    '2B': '2루타', '3B': '3루타', 'AB': '타수', 'AO': '뜬공', 'AVG': '타율',
    'BB': '볼넷', 'BB/K': '볼넷/삼진', 'CS': '도루실패', 'E': '실책', 'G': '경기',
    'GDP': '병살타', 'GO': '땅볼', 'GO/AO': '땅볼/뜬공', 'GPA': '(1.8x출루율+장타율)/4',
    'GW RBI': '결승타', 'H': '안타', 'HBP': '사구', 'HR': '홈런', 'IBB': '고의4구',
    'ISOP': '순수장타율', 'MH': '멀티히트', 'OBP': '출루율', 'OPS': '출루율+장타율',
    'P/PA': '투구수/타석', 'PA': '타석', 'PH-BA': '대타타율', 'R': '득점', 'RBI': '타점',
    'RISP': '득점권타율', 'SAC': '희생번트', 'SB': '도루', 'SF': '희생플라이', 'SLG': '장타율',
    'SO': '삼진', 'TB': '루타', 'XBH': '장타', 'XR': '추정득점',
    # 수비기록
    'A': '어시스트', 'CS': '도루저지', 'CS%': '도루저지율', 'DP': '병살', 'FPCT': '수비율',
    'GS': '선발경기', 'PB': '포일', 'PKO': '견제사', 'PO': '풋아웃', 'POS': '포지션',
    'SB': '도루허용', 'IP' : '수비이닝',
    # 주루기록
    'OOB': '주루사', 'SBA': '도루시도', 'SB%': '도루성공률'
}

# 타순 매핑
order_mapping = {
    2: '1번', 3: '2번', 4: '3번', 5: '4번', 6: '5번',
    7: '6번', 8: '7번', 9: '8번', 10: '9번',
    11: '상위(1~2번)', 12: '중심(3~5번)', 13: '하위(6~9번)'
}

# 사이트 접속
for tep in teps[:2] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('SK'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # HitterBasic/Basic2일 경우에만 불필요한 열 제거
            if tep == 'HitterBasic/Basic2':
                df = df.drop(columns=['순위', '선수명', '팀명', 'AVG'])

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) >= 4:  # HitterBasic/Basic2의 데이터가 존재하는 경우
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        df3 = dfs[2]  # HitterBasic/Basic2의 page1 결과
        df4 = dfs[3]  # HitterBasic/Basic2의 page2 결과
        Basic1_df = pd.concat([df1, df2], axis=0)
        Basic2_df = pd.concat([df3, df4], axis=0)
        final_df = pd.concat([Basic1_df, Basic2_df], axis=1)
    else:
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        final_df = pd.concat([df1, df2], axis=1)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'SSG_hitter_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[2:3] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('SK'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # HitterBasic/Detail1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Detail1c의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'SSG_hitter_detail_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[:1] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('SK'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 타순별 선택
        Situation_selector = '#cphContents_cphContents_cphContents_ddlSituation_ddlSituation > option:nth-child(14)'
        driver.find_element(By.CSS_SELECTOR, Situation_selector).click()
        time.sleep(3)

        for order in batting_order:
            # 타순 선택
            Batting_order_selector = f'#cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail > option:nth-child({order})'
            driver.find_element(By.CSS_SELECTOR, Batting_order_selector).click()
            time.sleep(3)

            # 1페이지로 돌아가기
            first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
            first_page_button.click()
            time.sleep(3)

            # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
            for page in range(1, 3):
                if page > 1:
                    try:
                        next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                        next_page_button.click()
                        time.sleep(3)
                    except:
                        break  # 페이지 버튼이 없는 경우 루프를 종료

                # 결과 테이블 가져오기
                result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
                table_html = result_table.get_attribute('outerHTML')

                # DataFrame으로 변환하여 리스트에 추가
                df = pd.read_html(table_html, encoding='utf-8')[0]

                # 타순 열 추가
                df['타순'] = order_mapping[order]

                # 결과를 리스트에 추가
                result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 결과 데이터프레임을 연도별로 합쳐서 각각의 CSV 파일로 저장
for year, dfs in result_dfs.items():
    if dfs:  # dfs 리스트가 비어있지 않을 때만 처리
        combined_df = pd.concat(dfs, axis=0)
        combined_df.rename(columns=column_translations, inplace=True)
        combined_df = combined_df.astype(str)
        combined_df.to_csv(os.path.join(folder_name, f'SSG_batting_order_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[3:4]:
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 수비 기록 접속
    for year_index, year in enumerate(Defense_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('SK'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 5):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 팀이 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if not dfs:
        continue  # dfs 리스트가 비어 있는 경우 반복문을 건너뜁니다.

    if len(dfs) >= 4 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        df4 = dfs[3]  # Defense/Basic의 page4 결과
        final_df = pd.concat([df1, df2, df3, df4], axis=0)
    elif len(dfs) >= 3 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        final_df = pd.concat([df1, df2, df3], axis=0)
    else :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'SSG_defense_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[4:] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 주루 기록 접속
    for year_index, year in enumerate(Runner_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('SK'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        df2 = dfs[1]  # Runner/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)
    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'SSG_runner_2024.csv'), index=False, encoding='cp949')

# 드라이버 종료
driver.quit()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3539841260.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3539841260.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3539841260.py:162: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3539841260.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3539841260.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3539841260.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3539841260.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3539841260.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3539841260.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3539841260.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3539841260.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3539841260.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3539841260.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3539841260.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3539841260.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3539841260.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3539841260.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3539841260.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3539841260.py:388: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]

# %% [markdown]
# # 두산

# %%
# 폴더 생성
folder_name = '두산'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# 1 Chrome 열기
driver = wd.Chrome()

teps = ['HitterBasic/Basic1', 'HitterBasic/Basic2', 'HitterBasic/Detail1', 'Defense/Basic', 'Runner/Basic']
Hitter_years = [37, 38, 39, 40, 41, 42]
Defense_years = Hitter_years
Runner_years = Defense_years
batting_order = range(2,14)
team = ['OB']

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 열 이름 사전
column_translations = {
    # 타자기록
    '2B': '2루타', '3B': '3루타', 'AB': '타수', 'AO': '뜬공', 'AVG': '타율',
    'BB': '볼넷', 'BB/K': '볼넷/삼진', 'CS': '도루실패', 'E': '실책', 'G': '경기',
    'GDP': '병살타', 'GO': '땅볼', 'GO/AO': '땅볼/뜬공', 'GPA': '(1.8x출루율+장타율)/4',
    'GW RBI': '결승타', 'H': '안타', 'HBP': '사구', 'HR': '홈런', 'IBB': '고의4구',
    'ISOP': '순수장타율', 'MH': '멀티히트', 'OBP': '출루율', 'OPS': '출루율+장타율',
    'P/PA': '투구수/타석', 'PA': '타석', 'PH-BA': '대타타율', 'R': '득점', 'RBI': '타점',
    'RISP': '득점권타율', 'SAC': '희생번트', 'SB': '도루', 'SF': '희생플라이', 'SLG': '장타율',
    'SO': '삼진', 'TB': '루타', 'XBH': '장타', 'XR': '추정득점',
    # 수비기록
    'A': '어시스트', 'CS': '도루저지', 'CS%': '도루저지율', 'DP': '병살', 'FPCT': '수비율',
    'GS': '선발경기', 'PB': '포일', 'PKO': '견제사', 'PO': '풋아웃', 'POS': '포지션',
    'SB': '도루허용', 'IP' : '수비이닝',
    # 주루기록
    'OOB': '주루사', 'SBA': '도루시도', 'SB%': '도루성공률'
}

# 타순 매핑
order_mapping = {
    2: '1번', 3: '2번', 4: '3번', 5: '4번', 6: '5번',
    7: '6번', 8: '7번', 9: '8번', 10: '9번',
    11: '상위(1~2번)', 12: '중심(3~5번)', 13: '하위(6~9번)'
}

# 사이트 접속
for tep in teps[:2] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('OB'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # HitterBasic/Basic2일 경우에만 불필요한 열 제거
            if tep == 'HitterBasic/Basic2':
                df = df.drop(columns=['순위', '선수명', '팀명', 'AVG'])

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) >= 4:  # HitterBasic/Basic2의 데이터가 존재하는 경우
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        df3 = dfs[2]  # HitterBasic/Basic2의 page1 결과
        df4 = dfs[3]  # HitterBasic/Basic2의 page2 결과
        Basic1_df = pd.concat([df1, df2], axis=0)
        Basic2_df = pd.concat([df3, df4], axis=0)
        final_df = pd.concat([Basic1_df, Basic2_df], axis=1)
    else:
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        final_df = pd.concat([df1, df2], axis=1)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'doosan_hitter_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[2:3] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('OB'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # HitterBasic/Detail1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Detail1c의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'doosan_hitter_detail_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[:1] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('OB'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 타순별 선택
        Situation_selector = '#cphContents_cphContents_cphContents_ddlSituation_ddlSituation > option:nth-child(14)'
        driver.find_element(By.CSS_SELECTOR, Situation_selector).click()
        time.sleep(3)

        for order in batting_order:
            # 타순 선택
            Batting_order_selector = f'#cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail > option:nth-child({order})'
            driver.find_element(By.CSS_SELECTOR, Batting_order_selector).click()
            time.sleep(3)

            # 1페이지로 돌아가기
            first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
            first_page_button.click()
            time.sleep(3)

            # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
            for page in range(1, 3):
                if page > 1:
                    try:
                        next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                        next_page_button.click()
                        time.sleep(3)
                    except:
                        break  # 페이지 버튼이 없는 경우 루프를 종료

                # 결과 테이블 가져오기
                result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
                table_html = result_table.get_attribute('outerHTML')

                # DataFrame으로 변환하여 리스트에 추가
                df = pd.read_html(table_html, encoding='utf-8')[0]

                # 타순 열 추가
                df['타순'] = order_mapping[order]

                # 결과를 리스트에 추가
                result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 결과 데이터프레임을 연도별로 합쳐서 각각의 CSV 파일로 저장
for year, dfs in result_dfs.items():
    if dfs:  # dfs 리스트가 비어있지 않을 때만 처리
        combined_df = pd.concat(dfs, axis=0)
        combined_df.rename(columns=column_translations, inplace=True)
        combined_df = combined_df.astype(str)
        combined_df.to_csv(os.path.join(folder_name, f'doosan_batting_order_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[3:4]:
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 수비 기록 접속
    for year_index, year in enumerate(Defense_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('OB'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 5):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 팀이 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if not dfs:
        continue  # dfs 리스트가 비어 있는 경우 반복문을 건너뜁니다.

    if len(dfs) >= 4 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        df4 = dfs[3]  # Defense/Basic의 page4 결과
        final_df = pd.concat([df1, df2, df3, df4], axis=0)
    elif len(dfs) >= 3 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        final_df = pd.concat([df1, df2, df3], axis=0)
    else :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'doosan_defense_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[4:] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 주루 기록 접속
    for year_index, year in enumerate(Runner_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('OB'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        df2 = dfs[1]  # Runner/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)
    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'doosan_runner_2024.csv'), index=False, encoding='cp949')

# 드라이버 종료
driver.quit()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:162: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:162: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:388: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1084652859.py:388: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]

# %% [markdown]
# # 롯데

# %%
# 폴더 생성
folder_name = '롯데'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# 1 Chrome 열기
driver = wd.Chrome()

teps = ['HitterBasic/Basic1', 'HitterBasic/Basic2', 'HitterBasic/Detail1', 'Defense/Basic', 'Runner/Basic']
Hitter_years = [37, 38, 39, 40, 41, 42]
Defense_years = Hitter_years
Runner_years = Defense_years
batting_order = range(2,14)
team = ['LT']

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 열 이름 사전
column_translations = {
    # 타자기록
    '2B': '2루타', '3B': '3루타', 'AB': '타수', 'AO': '뜬공', 'AVG': '타율',
    'BB': '볼넷', 'BB/K': '볼넷/삼진', 'CS': '도루실패', 'E': '실책', 'G': '경기',
    'GDP': '병살타', 'GO': '땅볼', 'GO/AO': '땅볼/뜬공', 'GPA': '(1.8x출루율+장타율)/4',
    'GW RBI': '결승타', 'H': '안타', 'HBP': '사구', 'HR': '홈런', 'IBB': '고의4구',
    'ISOP': '순수장타율', 'MH': '멀티히트', 'OBP': '출루율', 'OPS': '출루율+장타율',
    'P/PA': '투구수/타석', 'PA': '타석', 'PH-BA': '대타타율', 'R': '득점', 'RBI': '타점',
    'RISP': '득점권타율', 'SAC': '희생번트', 'SB': '도루', 'SF': '희생플라이', 'SLG': '장타율',
    'SO': '삼진', 'TB': '루타', 'XBH': '장타', 'XR': '추정득점',
    # 수비기록
    'A': '어시스트', 'CS': '도루저지', 'CS%': '도루저지율', 'DP': '병살', 'FPCT': '수비율',
    'GS': '선발경기', 'PB': '포일', 'PKO': '견제사', 'PO': '풋아웃', 'POS': '포지션',
    'SB': '도루허용', 'IP' : '수비이닝',
    # 주루기록
    'OOB': '주루사', 'SBA': '도루시도', 'SB%': '도루성공률'
}

# 타순 매핑
order_mapping = {
    2: '1번', 3: '2번', 4: '3번', 5: '4번', 6: '5번',
    7: '6번', 8: '7번', 9: '8번', 10: '9번',
    11: '상위(1~2번)', 12: '중심(3~5번)', 13: '하위(6~9번)'
}

# 사이트 접속
for tep in teps[:2] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('LT'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # HitterBasic/Basic2일 경우에만 불필요한 열 제거
            if tep == 'HitterBasic/Basic2':
                df = df.drop(columns=['순위', '선수명', '팀명', 'AVG'])

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) >= 4:  # HitterBasic/Basic2의 데이터가 존재하는 경우
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        df3 = dfs[2]  # HitterBasic/Basic2의 page1 결과
        df4 = dfs[3]  # HitterBasic/Basic2의 page2 결과
        Basic1_df = pd.concat([df1, df2], axis=0)
        Basic2_df = pd.concat([df3, df4], axis=0)
        final_df = pd.concat([Basic1_df, Basic2_df], axis=1)
    else:
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        final_df = pd.concat([df1, df2], axis=1)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'lotte_hitter_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[2:3] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('LT'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # HitterBasic/Detail1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Detail1c의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'lotte_hitter_detail_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[:1] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('LT'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 타순별 선택
        Situation_selector = '#cphContents_cphContents_cphContents_ddlSituation_ddlSituation > option:nth-child(14)'
        driver.find_element(By.CSS_SELECTOR, Situation_selector).click()
        time.sleep(3)

        for order in batting_order:
            # 타순 선택
            Batting_order_selector = f'#cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail > option:nth-child({order})'
            driver.find_element(By.CSS_SELECTOR, Batting_order_selector).click()
            time.sleep(3)

            # 1페이지로 돌아가기
            first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
            first_page_button.click()
            time.sleep(3)

            # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
            for page in range(1, 3):
                if page > 1:
                    try:
                        next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                        next_page_button.click()
                        time.sleep(3)
                    except:
                        break  # 페이지 버튼이 없는 경우 루프를 종료

                # 결과 테이블 가져오기
                result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
                table_html = result_table.get_attribute('outerHTML')

                # DataFrame으로 변환하여 리스트에 추가
                df = pd.read_html(table_html, encoding='utf-8')[0]

                # 타순 열 추가
                df['타순'] = order_mapping[order]

                # 결과를 리스트에 추가
                result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 결과 데이터프레임을 연도별로 합쳐서 각각의 CSV 파일로 저장
for year, dfs in result_dfs.items():
    if dfs:  # dfs 리스트가 비어있지 않을 때만 처리
        combined_df = pd.concat(dfs, axis=0)
        combined_df.rename(columns=column_translations, inplace=True)
        combined_df = combined_df.astype(str)
        combined_df.to_csv(os.path.join(folder_name, f'lotte_batting_order_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[3:4]:
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 수비 기록 접속
    for year_index, year in enumerate(Defense_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('LT'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 5):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 팀이 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if not dfs:
        continue  # dfs 리스트가 비어 있는 경우 반복문을 건너뜁니다.

    if len(dfs) >= 4 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        df4 = dfs[3]  # Defense/Basic의 page4 결과
        final_df = pd.concat([df1, df2, df3, df4], axis=0)
    elif len(dfs) >= 3 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        final_df = pd.concat([df1, df2, df3], axis=0)
    else :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'lotte_defense_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[4:] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 주루 기록 접속
    for year_index, year in enumerate(Runner_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('LT'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        df2 = dfs[1]  # Runner/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)
    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'lotte_runner_2024.csv'), index=False, encoding='cp949')

# 드라이버 종료
driver.quit()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\2742722688.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\2742722688.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\2742722688.py:162: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\2742722688.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\2742722688.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\2742722688.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\2742722688.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\2742722688.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\2742722688.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\2742722688.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\2742722688.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\2742722688.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\2742722688.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\2742722688.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\2742722688.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\2742722688.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\2742722688.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\2742722688.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\2742722688.py:388: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]

# %% [markdown]
# # 삼성

# %%
# 폴더 생성
folder_name = '삼성'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# 1 Chrome 열기
driver = wd.Chrome()

teps = ['HitterBasic/Basic1', 'HitterBasic/Basic2', 'HitterBasic/Detail1', 'Defense/Basic', 'Runner/Basic']
Hitter_years = [37, 38, 39, 40, 41, 42]
Defense_years = Hitter_years
Runner_years = Defense_years
batting_order = range(2,14)
team = ['SS']

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 열 이름 사전
column_translations = {
    # 타자기록
    '2B': '2루타', '3B': '3루타', 'AB': '타수', 'AO': '뜬공', 'AVG': '타율',
    'BB': '볼넷', 'BB/K': '볼넷/삼진', 'CS': '도루실패', 'E': '실책', 'G': '경기',
    'GDP': '병살타', 'GO': '땅볼', 'GO/AO': '땅볼/뜬공', 'GPA': '(1.8x출루율+장타율)/4',
    'GW RBI': '결승타', 'H': '안타', 'HBP': '사구', 'HR': '홈런', 'IBB': '고의4구',
    'ISOP': '순수장타율', 'MH': '멀티히트', 'OBP': '출루율', 'OPS': '출루율+장타율',
    'P/PA': '투구수/타석', 'PA': '타석', 'PH-BA': '대타타율', 'R': '득점', 'RBI': '타점',
    'RISP': '득점권타율', 'SAC': '희생번트', 'SB': '도루', 'SF': '희생플라이', 'SLG': '장타율',
    'SO': '삼진', 'TB': '루타', 'XBH': '장타', 'XR': '추정득점',
    # 수비기록
    'A': '어시스트', 'CS': '도루저지', 'CS%': '도루저지율', 'DP': '병살', 'FPCT': '수비율',
    'GS': '선발경기', 'PB': '포일', 'PKO': '견제사', 'PO': '풋아웃', 'POS': '포지션',
    'SB': '도루허용', 'IP' : '수비이닝',
    # 주루기록
    'OOB': '주루사', 'SBA': '도루시도', 'SB%': '도루성공률'
}

# 타순 매핑
order_mapping = {
    2: '1번', 3: '2번', 4: '3번', 5: '4번', 6: '5번',
    7: '6번', 8: '7번', 9: '8번', 10: '9번',
    11: '상위(1~2번)', 12: '중심(3~5번)', 13: '하위(6~9번)'
}

# 사이트 접속
for tep in teps[:2] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('SS'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # HitterBasic/Basic2일 경우에만 불필요한 열 제거
            if tep == 'HitterBasic/Basic2':
                df = df.drop(columns=['순위', '선수명', '팀명', 'AVG'])

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) >= 4:  # HitterBasic/Basic2의 데이터가 존재하는 경우
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        df3 = dfs[2]  # HitterBasic/Basic2의 page1 결과
        df4 = dfs[3]  # HitterBasic/Basic2의 page2 결과
        Basic1_df = pd.concat([df1, df2], axis=0)
        Basic2_df = pd.concat([df3, df4], axis=0)
        final_df = pd.concat([Basic1_df, Basic2_df], axis=1)
    else:
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        final_df = pd.concat([df1, df2], axis=1)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'Samsung_hitter_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[2:3] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('SS'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # HitterBasic/Detail1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Detail1c의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'Samsung_hitter_detail_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[:1] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('SS'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 타순별 선택
        Situation_selector = '#cphContents_cphContents_cphContents_ddlSituation_ddlSituation > option:nth-child(14)'
        driver.find_element(By.CSS_SELECTOR, Situation_selector).click()
        time.sleep(3)

        for order in batting_order:
            # 타순 선택
            Batting_order_selector = f'#cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail > option:nth-child({order})'
            driver.find_element(By.CSS_SELECTOR, Batting_order_selector).click()
            time.sleep(3)

            # 1페이지로 돌아가기
            first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
            first_page_button.click()
            time.sleep(3)

            # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
            for page in range(1, 3):
                if page > 1:
                    try:
                        next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                        next_page_button.click()
                        time.sleep(3)
                    except:
                        break  # 페이지 버튼이 없는 경우 루프를 종료

                # 결과 테이블 가져오기
                result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
                table_html = result_table.get_attribute('outerHTML')

                # DataFrame으로 변환하여 리스트에 추가
                df = pd.read_html(table_html, encoding='utf-8')[0]

                # 타순 열 추가
                df['타순'] = order_mapping[order]

                # 결과를 리스트에 추가
                result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 결과 데이터프레임을 연도별로 합쳐서 각각의 CSV 파일로 저장
for year, dfs in result_dfs.items():
    if dfs:  # dfs 리스트가 비어있지 않을 때만 처리
        combined_df = pd.concat(dfs, axis=0)
        combined_df.rename(columns=column_translations, inplace=True)
        combined_df = combined_df.astype(str)
        combined_df.to_csv(os.path.join(folder_name, f'Samsung_batting_order_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[3:4]:
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 수비 기록 접속
    for year_index, year in enumerate(Defense_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('SS'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 5):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 팀이 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if not dfs:
        continue  # dfs 리스트가 비어 있는 경우 반복문을 건너뜁니다.

    if len(dfs) >= 4 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        df4 = dfs[3]  # Defense/Basic의 page4 결과
        final_df = pd.concat([df1, df2, df3, df4], axis=0)
    elif len(dfs) >= 3 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        final_df = pd.concat([df1, df2, df3], axis=0)
    else :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'Samsung_defense_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[4:] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 주루 기록 접속
    for year_index, year in enumerate(Runner_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('SS'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        df2 = dfs[1]  # Runner/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)
    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'Samsung_runner_2024.csv'), index=False, encoding='cp949')

# 드라이버 종료
driver.quit()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:162: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:162: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:388: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\268191558.py:388: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]

# %% [markdown]
# # 키움

# %%
# 폴더 생성
folder_name = '키움'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# 1 Chrome 열기
driver = wd.Chrome()

teps = ['HitterBasic/Basic1', 'HitterBasic/Basic2', 'HitterBasic/Detail1', 'Defense/Basic', 'Runner/Basic']
Hitter_years = [37, 38, 39, 40, 41, 42]
Defense_years = Hitter_years
Runner_years = Defense_years
batting_order = range(2,14)
team = ['WO']

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 열 이름 사전
column_translations = {
    # 타자기록
    '2B': '2루타', '3B': '3루타', 'AB': '타수', 'AO': '뜬공', 'AVG': '타율',
    'BB': '볼넷', 'BB/K': '볼넷/삼진', 'CS': '도루실패', 'E': '실책', 'G': '경기',
    'GDP': '병살타', 'GO': '땅볼', 'GO/AO': '땅볼/뜬공', 'GPA': '(1.8x출루율+장타율)/4',
    'GW RBI': '결승타', 'H': '안타', 'HBP': '사구', 'HR': '홈런', 'IBB': '고의4구',
    'ISOP': '순수장타율', 'MH': '멀티히트', 'OBP': '출루율', 'OPS': '출루율+장타율',
    'P/PA': '투구수/타석', 'PA': '타석', 'PH-BA': '대타타율', 'R': '득점', 'RBI': '타점',
    'RISP': '득점권타율', 'SAC': '희생번트', 'SB': '도루', 'SF': '희생플라이', 'SLG': '장타율',
    'SO': '삼진', 'TB': '루타', 'XBH': '장타', 'XR': '추정득점',
    # 수비기록
    'A': '어시스트', 'CS': '도루저지', 'CS%': '도루저지율', 'DP': '병살', 'FPCT': '수비율',
    'GS': '선발경기', 'PB': '포일', 'PKO': '견제사', 'PO': '풋아웃', 'POS': '포지션',
    'SB': '도루허용', 'IP' : '수비이닝',
    # 주루기록
    'OOB': '주루사', 'SBA': '도루시도', 'SB%': '도루성공률'
}

# 타순 매핑
order_mapping = {
    2: '1번', 3: '2번', 4: '3번', 5: '4번', 6: '5번',
    7: '6번', 8: '7번', 9: '8번', 10: '9번',
    11: '상위(1~2번)', 12: '중심(3~5번)', 13: '하위(6~9번)'
}

# 사이트 접속
for tep in teps[:2] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('WO'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # HitterBasic/Basic2일 경우에만 불필요한 열 제거
            if tep == 'HitterBasic/Basic2':
                df = df.drop(columns=['순위', '선수명', '팀명', 'AVG'])

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) >= 4:  # HitterBasic/Basic2의 데이터가 존재하는 경우
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        df3 = dfs[2]  # HitterBasic/Basic2의 page1 결과
        df4 = dfs[3]  # HitterBasic/Basic2의 page2 결과
        Basic1_df = pd.concat([df1, df2], axis=0)
        Basic2_df = pd.concat([df3, df4], axis=0)
        final_df = pd.concat([Basic1_df, Basic2_df], axis=1)
    else:
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        final_df = pd.concat([df1, df2], axis=1)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'kiwoom_hitter_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[2:3] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('WO'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # HitterBasic/Detail1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Detail1c의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'kiwoom_hitter_detail_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[:1] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('WO'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 타순별 선택
        Situation_selector = '#cphContents_cphContents_cphContents_ddlSituation_ddlSituation > option:nth-child(14)'
        driver.find_element(By.CSS_SELECTOR, Situation_selector).click()
        time.sleep(3)

        for order in batting_order:
            # 타순 선택
            Batting_order_selector = f'#cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail > option:nth-child({order})'
            driver.find_element(By.CSS_SELECTOR, Batting_order_selector).click()
            time.sleep(3)

            # 1페이지로 돌아가기
            first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
            first_page_button.click()
            time.sleep(3)

            # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
            for page in range(1, 3):
                if page > 1:
                    try:
                        next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                        next_page_button.click()
                        time.sleep(3)
                    except:
                        break  # 페이지 버튼이 없는 경우 루프를 종료

                # 결과 테이블 가져오기
                result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
                table_html = result_table.get_attribute('outerHTML')

                # DataFrame으로 변환하여 리스트에 추가
                df = pd.read_html(table_html, encoding='utf-8')[0]

                # 타순 열 추가
                df['타순'] = order_mapping[order]

                # 결과를 리스트에 추가
                result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 결과 데이터프레임을 연도별로 합쳐서 각각의 CSV 파일로 저장
for year, dfs in result_dfs.items():
    if dfs:  # dfs 리스트가 비어있지 않을 때만 처리
        combined_df = pd.concat(dfs, axis=0)
        combined_df.rename(columns=column_translations, inplace=True)
        combined_df = combined_df.astype(str)
        combined_df.to_csv(os.path.join(folder_name, f'kiwoom_batting_order_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[3:4]:
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 수비 기록 접속
    for year_index, year in enumerate(Defense_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('WO'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 5):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 팀이 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if not dfs:
        continue  # dfs 리스트가 비어 있는 경우 반복문을 건너뜁니다.

    if len(dfs) >= 4 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        df4 = dfs[3]  # Defense/Basic의 page4 결과
        final_df = pd.concat([df1, df2, df3, df4], axis=0)
    elif len(dfs) >= 3 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        final_df = pd.concat([df1, df2, df3], axis=0)
    else :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'kiwoom_defense_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[4:] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 주루 기록 접속
    for year_index, year in enumerate(Runner_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('WO'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        df2 = dfs[1]  # Runner/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)
    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'kiwoom_runner_2024.csv'), index=False, encoding='cp949')

# 드라이버 종료
driver.quit()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:162: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:162: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:388: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\1371885359.py:388: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]

# %% [markdown]
# # 한화

# %%
# 폴더 생성
folder_name = '한화'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# 1 Chrome 열기
driver = wd.Chrome()

teps = ['HitterBasic/Basic1', 'HitterBasic/Basic2', 'HitterBasic/Detail1', 'Defense/Basic', 'Runner/Basic']
Hitter_years = [37, 38, 39, 40, 41, 42]
Defense_years = Hitter_years
Runner_years = Defense_years
batting_order = range(2,14)
team = ['HH']

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 열 이름 사전
column_translations = {
    # 타자기록
    '2B': '2루타', '3B': '3루타', 'AB': '타수', 'AO': '뜬공', 'AVG': '타율',
    'BB': '볼넷', 'BB/K': '볼넷/삼진', 'CS': '도루실패', 'E': '실책', 'G': '경기',
    'GDP': '병살타', 'GO': '땅볼', 'GO/AO': '땅볼/뜬공', 'GPA': '(1.8x출루율+장타율)/4',
    'GW RBI': '결승타', 'H': '안타', 'HBP': '사구', 'HR': '홈런', 'IBB': '고의4구',
    'ISOP': '순수장타율', 'MH': '멀티히트', 'OBP': '출루율', 'OPS': '출루율+장타율',
    'P/PA': '투구수/타석', 'PA': '타석', 'PH-BA': '대타타율', 'R': '득점', 'RBI': '타점',
    'RISP': '득점권타율', 'SAC': '희생번트', 'SB': '도루', 'SF': '희생플라이', 'SLG': '장타율',
    'SO': '삼진', 'TB': '루타', 'XBH': '장타', 'XR': '추정득점',
    # 수비기록
    'A': '어시스트', 'CS': '도루저지', 'CS%': '도루저지율', 'DP': '병살', 'FPCT': '수비율',
    'GS': '선발경기', 'PB': '포일', 'PKO': '견제사', 'PO': '풋아웃', 'POS': '포지션',
    'SB': '도루허용', 'IP' : '수비이닝',
    # 주루기록
    'OOB': '주루사', 'SBA': '도루시도', 'SB%': '도루성공률'
}

# 타순 매핑
order_mapping = {
    2: '1번', 3: '2번', 4: '3번', 5: '4번', 6: '5번',
    7: '6번', 8: '7번', 9: '8번', 10: '9번',
    11: '상위(1~2번)', 12: '중심(3~5번)', 13: '하위(6~9번)'
}

# 사이트 접속
for tep in teps[:2] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('HH'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # HitterBasic/Basic2일 경우에만 불필요한 열 제거
            if tep == 'HitterBasic/Basic2':
                df = df.drop(columns=['순위', '선수명', '팀명', 'AVG'])

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) >= 4:  # HitterBasic/Basic2의 데이터가 존재하는 경우
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        df3 = dfs[2]  # HitterBasic/Basic2의 page1 결과
        df4 = dfs[3]  # HitterBasic/Basic2의 page2 결과
        Basic1_df = pd.concat([df1, df2], axis=0)
        Basic2_df = pd.concat([df3, df4], axis=0)
        final_df = pd.concat([Basic1_df, Basic2_df], axis=1)
    else:
        df1 = dfs[0]  # HitterBasic/Basic1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Basic1의 page2 결과
        final_df = pd.concat([df1, df2], axis=1)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'Hanhwa_hitter_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[2:3] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('HH'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # HitterBasic/Detail1의 page1 결과
        df2 = dfs[1]  # HitterBasic/Detail1c의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'Hanhwa_hitter_detail_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[:1] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 타자 기록 접속
    for year_index, year in enumerate(Hitter_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('HH'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 타순별 선택
        Situation_selector = '#cphContents_cphContents_cphContents_ddlSituation_ddlSituation > option:nth-child(14)'
        driver.find_element(By.CSS_SELECTOR, Situation_selector).click()
        time.sleep(3)

        for order in batting_order:
            # 타순 선택
            Batting_order_selector = f'#cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail > option:nth-child({order})'
            driver.find_element(By.CSS_SELECTOR, Batting_order_selector).click()
            time.sleep(3)

            # 1페이지로 돌아가기
            first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
            first_page_button.click()
            time.sleep(3)

            # 페이지 반복하여 데이터 가져오기 (1페이지와 2페이지)
            for page in range(1, 3):
                if page > 1:
                    try:
                        next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                        next_page_button.click()
                        time.sleep(3)
                    except:
                        break  # 페이지 버튼이 없는 경우 루프를 종료

                # 결과 테이블 가져오기
                result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
                table_html = result_table.get_attribute('outerHTML')

                # DataFrame으로 변환하여 리스트에 추가
                df = pd.read_html(table_html, encoding='utf-8')[0]

                # 타순 열 추가
                df['타순'] = order_mapping[order]

                # 결과를 리스트에 추가
                result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 결과 데이터프레임을 연도별로 합쳐서 각각의 CSV 파일로 저장
for year, dfs in result_dfs.items():
    if dfs:  # dfs 리스트가 비어있지 않을 때만 처리
        combined_df = pd.concat(dfs, axis=0)
        combined_df.rename(columns=column_translations, inplace=True)
        combined_df = combined_df.astype(str)
        combined_df.to_csv(os.path.join(folder_name, f'Hanhwa_batting_order_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[3:4]:
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 수비 기록 접속
    for year_index, year in enumerate(Defense_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('HH'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 5):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 팀이 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if not dfs:
        continue  # dfs 리스트가 비어 있는 경우 반복문을 건너뜁니다.

    if len(dfs) >= 4 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        df4 = dfs[3]  # Defense/Basic의 page4 결과
        final_df = pd.concat([df1, df2, df3, df4], axis=0)
    elif len(dfs) >= 3 :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        df3 = dfs[2]  # Defense/Basic의 page3 결과
        final_df = pd.concat([df1, df2, df3], axis=0)
    else :
        df1 = dfs[0]  # Defense/Basic의 page1 결과
        df2 = dfs[1]  # Defense/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'Hanhwa_defense_2024.csv'), index=False, encoding='cp949')

# 빈 결과 테이블
result_dfs = {year: [] for year in range(2019, 2019 + len(Hitter_years))}

# 사이트 접속
for tep in teps[4:] :
    url = f'https://www.koreabaseball.com/Record/Player/{tep}.aspx'
    driver.get(url)
    time.sleep(3)

    # 주루 기록 접속
    for year_index, year in enumerate(Runner_years):
        # 연도 선택
        Season_selector = f'#cphContents_cphContents_cphContents_ddlSeason_ddlSeason > option:nth-child({year})'
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

        # 팀 정보 선택 ('HH'로 설정)
        team_option = driver.find_element(By.CSS_SELECTOR, f"option[value='{team[0]}']")
        team_option.click()
        time.sleep(3)

        # 1페이지로 돌아가기
        first_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo1')
        first_page_button.click()
        time.sleep(3)

        # 페이지 반복하여 데이터 가져오기 (1페이지~ 4페이지)
        for page in range(1, 3):
            if page > 1:
                try:
                    next_page_button = driver.find_element(By.CSS_SELECTOR, f'#cphContents_cphContents_cphContents_ucPager_btnNo{page}')
                    next_page_button.click()
                    time.sleep(3)
                except:
                    break  # 페이지 버튼이 없는 경우 루프를 종료

            # 결과 테이블 가져오기
            result_table = driver.find_element(By.CSS_SELECTOR, '#cphContents_cphContents_cphContents_udpContent > div.record_result')
            table_html = result_table.get_attribute('outerHTML')

            # DataFrame으로 변환하여 리스트에 추가
            df = pd.read_html(table_html, encoding='utf-8')[0]

            # 결과를 리스트에 추가
            result_dfs[2019 + year_index].append(df)

        # 연도가 바뀔 때마다 다시 첫 페이지로 돌아가기
        driver.get(url)
        time.sleep(3)
        driver.find_element(By.CSS_SELECTOR, Season_selector).click()
        time.sleep(3)

# 각 연도별로 DataFrame을 CSV 파일로 저장
for year, dfs in result_dfs.items():
    # dfs 개수에 따라 다르게 저장
    if len(dfs) > 1 :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        df2 = dfs[1]  # Runner/Basic의 page2 결과
        final_df = pd.concat([df1, df2], axis=0)
    else :
        df1 = dfs[0]  # Runner/Basic의 page1 결과
        final_df = df1

    # 열 이름을 한국어로 변환
    final_df.rename(columns=column_translations, inplace=True)

    # 데이터프레임 전체를 문자열로 변환하여 CSV 파일로 저장
    final_df = final_df.astype(str)
    final_df.to_csv(os.path.join(folder_name, f'Hanhwa_runner_2024.csv'), index=False, encoding='cp949')

# 드라이버 종료
driver.quit()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3149810655.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3149810655.py:83: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3149810655.py:162: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3149810655.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3149810655.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3149810655.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3149810655.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3149810655.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3149810655.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3149810655.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3149810655.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3149810655.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3149810655.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3149810655.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3149810655.py:244: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3149810655.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3149810655.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3149810655.py:307: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30644\3149810655.py:388: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html, encoding='utf-8')[0]
